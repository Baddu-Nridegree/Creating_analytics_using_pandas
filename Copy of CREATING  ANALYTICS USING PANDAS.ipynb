# %%
import random

# %%
import pandas as pd

# %%
from google.colab import drive

# %%
# Mount the drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd

# %%
# read file from the drive
import pandas as pd

# %%
dataset ='/content/drive/MyDrive/matches_1930_2022.csv'

# %%
df = pd.read_csv(dataset)

# %%
df
# Out:
#          home_team away_team  home_score  home_xg  home_penalty  away_score  \
# 0        Argentina    France           3      3.3           4.0           3
# 1          Croatia   Morocco           2      0.7           NaN           1
# 2           France   Morocco           2      2.0           NaN           0
# 3        Argentina   Croatia           3      2.3           NaN           0
# 4          Morocco  Portugal           1      1.4           NaN           0
# ..             ...       ...         ...      ...           ...         ...
# 959      Argentina    France           1      NaN           NaN           0
# 960     Yugoslavia    Brazil           2      NaN           NaN           1
# 961        Romania      Peru           3      NaN           NaN           1
# 962  United States   Belgium           3      NaN           NaN           0
# 963         France    Mexico           4      NaN           NaN           1
#
#      away_xg  away_penalty      home_manager          home_captain  ...  \
# 0        2.2           2.0    Lionel Scaloni          Lionel Messi  ...
# 1        1.2           NaN      Zlatko Dalić           Luka Modrić  ...
# 2        0.9           NaN  Didier Deschamps           Hugo Lloris  ...
# 3        0.5           NaN    Lionel Scaloni          Lionel Messi  ...
# 4        0.9           NaN   Hoalid Regragui          Romain Saïss  ...
# ..       ...           ...               ...                   ...  ...
# 959      NaN           NaN  Francisco Olazar       Manuel Ferreira  ...
# 960      NaN           NaN   Bosko Simonovic       Milutin Ivković  ...
# 961      NaN           NaN     Octav Luchide          Emerich Vogl  ...
# 962      NaN           NaN        Bob Millar            Tom Florie  ...
# 963      NaN           NaN     Raoul Caudron  Alexandre Villaplane  ...
#
#     home_penalty_shootout_miss_long  \
# 0                               NaN
# 1                               NaN
# 2                               NaN
# 3                               NaN
# 4                               NaN
# ..                              ...
# 959                             NaN
# 960                             NaN
# 961                             NaN
# 962                             NaN
# 963                             NaN
#
#                        away_penalty_shootout_miss_long  home_red_card  \
# 0    ['3|1:1|Kingsley Coman', '5|2:1|Aurélien Tchou...            NaN
# 1                                                  NaN            NaN
# 2                                                  NaN            NaN
# 3                                                  NaN            NaN
# 4                                                  NaN            NaN
# ..                                                 ...            ...
# 959                                                NaN            NaN
# 960                                                NaN            NaN
# 961                                                NaN            NaN
# 962                                                NaN            NaN
# 963                                                NaN            NaN
#
#             away_red_card   home_yellow_red_card away_yellow_red_card  \
# 0                     NaN                    NaN                  NaN
# 1                     NaN                    NaN                  NaN
# 2                     NaN                    NaN                  NaN
# 3                     NaN                    NaN                  NaN
# 4                     NaN  Walid Cheddira · 90+3                  NaN
# ..                    ...                    ...                  ...
# 959                   NaN                    NaN                  NaN
# 960                   NaN                    NaN                  NaN
# 961  Plácido Galindo · 70                    NaN                  NaN
# 962                   NaN                    NaN                  NaN
# 963                   NaN                    NaN                  NaN
#
#                                  home_yellow_card_long  \
# 0    ['45+7&rsquor;|2:0|Enzo Fernández', '90+8&rsqu...
# 1                                                  NaN
# 2                                                  NaN
# 3    ['68&rsquor;|2:0|Cristian Romero', '71&rsquor;...
# 4    ['70&rsquor;|1:0|Achraf Dari', '90+1&rsquor;|1...
# ..                                                 ...
# 959                                                NaN
# 960                                                NaN
# 961                                                NaN
# 962                                                NaN
# 963                                                NaN
#
#                                  away_yellow_card_long  \
# 0    ['55&rsquor;|2:0|Adrien Rabiot', '87&rsquor;|2...
# 1    ['69&rsquor;|2:1|Azzedine Ounahi', '84&rsquor;...
# 2                    ['27&rsquor;|1:0|Sofiane Boufal']
# 3    ['32&rsquor;|0:0|Mateo Kovačić', '32&rsquor;|0...
# 4                           ['87&rsquor;|1:0|Vitinha']
# ..                                                 ...
# 959                                                NaN
# 960                                                NaN
# 961                                                NaN
# 962                                                NaN
# 963                                                NaN
#
#                                home_substitute_in_long  \
# 0    ['64&rsquor;|2:0|Marcos Acuña|for Ángel Di Mar...
# 1    ['61&rsquor;|2:1|Nikola Vlašić|for Andrej Kram...
# 2    ['65&rsquor;|1:0|Marcus Thuram|for Olivier Gir...
# 3    ['62&rsquor;|2:0|Lisandro Martínez|for Leandro...
# 4    ['57&rsquor;|1:0|Achraf Dari|for Romain Saïss'...
# ..                                                 ...
# 959                                                NaN
# 960                                                NaN
# 961                                                NaN
# 962                                                NaN
# 963                                                NaN
#
#                                away_substitute_in_long
# 0    ['41&rsquor;|2:0|Randal Kolo Muani|for Ousmane...
# 1    ['46&rsquor;|2:1|Ilias Chair|for Abdelhamid Sa...
# 2    ['21&rsquor;|1:0|Selim Amallah|for Romain Saïs...
# 3    ['46&rsquor;|2:0|Mislav Oršić|for Borna Sosa',...
# 4    ['51&rsquor;|1:0|João Cancelo|for Raphaël Guer...
# ..                                                 ...
# 959                                                NaN
# 960                                                NaN
# 961                                                NaN
# 962                                                NaN
# 963                                                NaN
#
# [964 rows x 44 columns]

# %%
df.columns
# Out:
# Index(['home_team', 'away_team', 'home_score', 'home_xg', 'home_penalty',
#        'away_score', 'away_xg', 'away_penalty', 'home_manager', 'home_captain',
#        'away_manager', 'away_captain', 'Attendance', 'Venue', 'Officials',
#        'Round', 'Date', 'Score', 'Referee', 'Notes', 'Host', 'Year',
#        'home_goal', 'away_goal', 'home_goal_long', 'away_goal_long',
#        'home_own_goal', 'away_own_goal', 'home_penalty_goal',
#        'away_penalty_goal', 'home_penalty_miss_long', 'away_penalty_miss_long',
#        'home_penalty_shootout_goal_long', 'away_penalty_shootout_goal_long',
#        'home_penalty_shootout_miss_long', 'away_penalty_shootout_miss_long',
#        'home_red_card', 'away_red_card', 'home_yellow_red_card',
#        'away_yellow_red_card', 'home_yellow_card_long',
#        'away_yellow_card_long', 'home_substitute_in_long',
#        'away_substitute_in_long'],
#       dtype='object')

# %%
df['home_team'].info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 964 entries, 0 to 963
# Series name: home_team
# Non-Null Count  Dtype
# --------------  -----
# 964 non-null    object
# dtypes: object(1)
# memory usage: 7.7+ KB

# %%
df['home_team'].value_counts()
# Out:
# home_team
# Brazil                    85
# Argentina                 59
# Italy                     57
# England                   40
# Germany                   40
#                           ..
# Jamaica                    1
# FR Yugoslavia              1
# Angola                     1
# Trinidad and Tobago        1
# Bosnia and Herzegovina     1
# Name: count, Length: 82, dtype: int64

# %%
df['Date'].value_counts()
# Out:
# Date
# 1958-06-15    8
# 1958-06-08    8
# 1934-05-27    8
# 1958-06-11    7
# 1938-06-05    6
#              ..
# 2006-07-08    1
# 2006-07-05    1
# 2006-07-04    1
# 1966-07-25    1
# 2022-12-18    1
# Name: count, Length: 378, dtype: int64

# %%
df['Score'].value_counts()
# Out:
# Score
# 1–0            118
# 2–1            107
# 1–1             75
# 2–0             71
# 0–0             66
#               ...
# (4) 2–2 (3)      1
# (3) 0–0 (2)      1
# (4) 2–2 (5)      1
# (4) 1–1 (3)      1
# 6–5              1
# Name: count, Length: 71, dtype: int64

# %%
ScoreAboveZero = df ['Score']>'0_0'

# %%
df[ScoreAboveZero]
# Out:
#          home_team away_team  home_score  home_xg  home_penalty  away_score  \
# 1          Croatia   Morocco           2      0.7           NaN           1
# 2           France   Morocco           2      2.0           NaN           0
# 3        Argentina   Croatia           3      2.3           NaN           0
# 4          Morocco  Portugal           1      1.4           NaN           0
# 5          England    France           1      2.4           NaN           2
# ..             ...       ...         ...      ...           ...         ...
# 959      Argentina    France           1      NaN           NaN           0
# 960     Yugoslavia    Brazil           2      NaN           NaN           1
# 961        Romania      Peru           3      NaN           NaN           1
# 962  United States   Belgium           3      NaN           NaN           0
# 963         France    Mexico           4      NaN           NaN           1
#
#      away_xg  away_penalty      home_manager          home_captain  ...  \
# 1        1.2           NaN      Zlatko Dalić           Luka Modrić  ...
# 2        0.9           NaN  Didier Deschamps           Hugo Lloris  ...
# 3        0.5           NaN    Lionel Scaloni          Lionel Messi  ...
# 4        0.9           NaN   Hoalid Regragui          Romain Saïss  ...
# 5        0.9           NaN  Gareth Southgate            Harry Kane  ...
# ..       ...           ...               ...                   ...  ...
# 959      NaN           NaN  Francisco Olazar       Manuel Ferreira  ...
# 960      NaN           NaN   Bosko Simonovic       Milutin Ivković  ...
# 961      NaN           NaN     Octav Luchide          Emerich Vogl  ...
# 962      NaN           NaN        Bob Millar            Tom Florie  ...
# 963      NaN           NaN     Raoul Caudron  Alexandre Villaplane  ...
#
#     home_penalty_shootout_miss_long away_penalty_shootout_miss_long  \
# 1                               NaN                             NaN
# 2                               NaN                             NaN
# 3                               NaN                             NaN
# 4                               NaN                             NaN
# 5                               NaN                             NaN
# ..                              ...                             ...
# 959                             NaN                             NaN
# 960                             NaN                             NaN
# 961                             NaN                             NaN
# 962                             NaN                             NaN
# 963                             NaN                             NaN
#
#      home_red_card         away_red_card   home_yellow_red_card  \
# 1              NaN                   NaN                    NaN
# 2              NaN                   NaN                    NaN
# 3              NaN                   NaN                    NaN
# 4              NaN                   NaN  Walid Cheddira · 90+3
# 5              NaN                   NaN                    NaN
# ..             ...                   ...                    ...
# 959            NaN                   NaN                    NaN
# 960            NaN                   NaN                    NaN
# 961            NaN  Plácido Galindo · 70                    NaN
# 962            NaN                   NaN                    NaN
# 963            NaN                   NaN                    NaN
#
#     away_yellow_red_card                              home_yellow_card_long  \
# 1                    NaN                                                NaN
# 2                    NaN                                                NaN
# 3                    NaN  ['68&rsquor;|2:0|Cristian Romero', '71&rsquor;...
# 4                    NaN  ['70&rsquor;|1:0|Achraf Dari', '90+1&rsquor;|1...
# 5                    NaN                   ['90&rsquor;|1:2|Harry Maguire']
# ..                   ...                                                ...
# 959                  NaN                                                NaN
# 960                  NaN                                                NaN
# 961                  NaN                                                NaN
# 962                  NaN                                                NaN
# 963                  NaN                                                NaN
#
#                                  away_yellow_card_long  \
# 1    ['69&rsquor;|2:1|Azzedine Ounahi', '84&rsquor;...
# 2                    ['27&rsquor;|1:0|Sofiane Boufal']
# 3    ['32&rsquor;|0:0|Mateo Kovačić', '32&rsquor;|0...
# 4                           ['87&rsquor;|1:0|Vitinha']
# 5    ['43&rsquor;|0:1|Antoine Griezmann', '47&rsquo...
# ..                                                 ...
# 959                                                NaN
# 960                                                NaN
# 961                                                NaN
# 962                                                NaN
# 963                                                NaN
#
#                                home_substitute_in_long  \
# 1    ['61&rsquor;|2:1|Nikola Vlašić|for Andrej Kram...
# 2    ['65&rsquor;|1:0|Marcus Thuram|for Olivier Gir...
# 3    ['62&rsquor;|2:0|Lisandro Martínez|for Leandro...
# 4    ['57&rsquor;|1:0|Achraf Dari|for Romain Saïss'...
# 5    ['79&rsquor;|1:2|Raheem Sterling|for Bukayo Sa...
# ..                                                 ...
# 959                                                NaN
# 960                                                NaN
# 961                                                NaN
# 962                                                NaN
# 963                                                NaN
#
#                                away_substitute_in_long
# 1    ['46&rsquor;|2:1|Ilias Chair|for Abdelhamid Sa...
# 2    ['21&rsquor;|1:0|Selim Amallah|for Romain Saïs...
# 3    ['46&rsquor;|2:0|Mislav Oršić|for Borna Sosa',...
# 4    ['51&rsquor;|1:0|João Cancelo|for Raphaël Guer...
# 5    ['79&rsquor;|1:2|Kingsley Coman|for Ousmane De...
# ..                                                 ...
# 959                                                NaN
# 960                                                NaN
# 961                                                NaN
# 962                                                NaN
# 963                                                NaN
#
# [929 rows x 44 columns]

# %%
ScoreByBrazil = df['home_team'] =='Brazil'

# %%
df[ScoreAboveZero & ScoreByBrazil].sort_values(by = 'home_score')
# Out:
#     home_team       away_team  home_score  home_xg  home_penalty  away_score  \
# 512    Brazil       Argentina           0      NaN           NaN           1
# 261    Brazil          France           0      NaN           NaN           1
# 695    Brazil          Poland           0      NaN           NaN           1
# 817    Brazil  Czechoslovakia           0      NaN           NaN           0
# 679    Brazil           Spain           0      NaN           NaN           0
# ..        ...             ...         ...      ...           ...         ...
# 887    Brazil          Mexico           5      NaN           NaN           0
# 831    Brazil          France           5      NaN           NaN           2
# 891    Brazil           Spain           6      NaN           NaN           1
# 926    Brazil          Poland           6      NaN           NaN           5
# 893    Brazil          Sweden           7      NaN           NaN           1
#
#      away_xg  away_penalty             home_manager  \
# 512      NaN           NaN       Sebastiao Lazaroni
# 261      NaN           NaN  Carlos Alberto Parreira
# 695      NaN           NaN            Mario Zagallo
# 817      NaN           NaN           Aymore Moreira
# 679      NaN           NaN         Claudio Coutinho
# ..       ...           ...                      ...
# 887      NaN           NaN             Zeze Moreira
# 831      NaN           NaN            Vicente Feola
# 891      NaN           NaN             Flavio Costa
# 926      NaN           NaN           Ademar Pimenta
# 893      NaN           NaN             Flavio Costa
#
#                   home_captain  ... home_penalty_shootout_miss_long  \
# 512              Ricardo Gomes  ...                             NaN
# 261                        NaN  ...                             NaN
# 695              Marinho Peres  ...                             NaN
# 817                Mauro Ramos  ...                             NaN
# 679               Émerson Leão  ...                             NaN
# ..                         ...  ...                             ...
# 887                      Bauer  ...                             NaN
# 831         Hilderaldo Bellini  ...                             NaN
# 891           Augusto da Costa  ...                             NaN
# 926  Martim Mércio da Silveira  ...                             NaN
# 893           Augusto da Costa  ...                             NaN
#
#     away_penalty_shootout_miss_long       home_red_card away_red_card  \
# 512                             NaN  Ricardo Gomes · 85           NaN
# 261                             NaN                 NaN           NaN
# 695                             NaN                 NaN           NaN
# 817                             NaN                 NaN           NaN
# 679                             NaN                 NaN           NaN
# ..                              ...                 ...           ...
# 887                             NaN                 NaN           NaN
# 831                             NaN                 NaN           NaN
# 891                             NaN                 NaN           NaN
# 926                             NaN                 NaN           NaN
# 893                             NaN                 NaN           NaN
#
#     home_yellow_red_card away_yellow_red_card  \
# 512                  NaN                  NaN
# 261                  NaN                  NaN
# 695                  NaN                  NaN
# 817                  NaN                  NaN
# 679                  NaN                  NaN
# ..                   ...                  ...
# 887                  NaN                  NaN
# 831                  NaN                  NaN
# 891                  NaN                  NaN
# 926                  NaN                  NaN
# 893                  NaN                  NaN
#
#                                  home_yellow_card_long  \
# 512  ['40&rsquor;|0:0|Ricardo Rocha', '50&rsquor;|0...
# 261  ['25&rsquor;|0:0|Cafú', '45&rsquor;|0:0|Juan',...
# 695                       ['76&rsquor;|0:1|Jairzinho']
# 817                                                NaN
# 679                                                NaN
# ..                                                 ...
# 887                                                NaN
# 831                                                NaN
# 891                           ['1&rsquor;|0:0|Bigode']
# 926                                                NaN
# 893                                                NaN
#
#                                  away_yellow_card_long  \
# 512  ['27&rsquor;|0:0|Pedro Monzón', '28&rsquor;|0:...
# 261  ['74&rsquor;|0:1|Willy Sagnol', '87&rsquor;|0:...
# 695               ['71&rsquor;|0:0|Henryk Kasperczak']
# 817                                                NaN
# 679                     ['1&rsquor;|0:0|Eugenio Leal']
# ..                                                 ...
# 887                                                NaN
# 831                                                NaN
# 891                                                NaN
# 926                                                NaN
# 893                                                NaN
#
#                                home_substitute_in_long  \
# 512  ['83&rsquor;|0:1|Silas Pereira', '83&rsquor;|0...
# 261  ['63&rsquor;|0:1|Adriano|for Juninho Pernambuc...
# 695   ['66&rsquor;|0:0|Mirandinha|for Ademir da Guia']
# 817                                                NaN
# 679  ['70&rsquor;|0:0|Gilberto Alves|for Nelinho', ...
# ..                                                 ...
# 887                                                NaN
# 831                                                NaN
# 891                                                NaN
# 926                                                NaN
# 893                                                NaN
#
#                                away_substitute_in_long
# 512  ['61&rsquor;|0:0|Gabriel Calderón|for Pedro Tr...
# 261  ['77&rsquor;|0:1|Sidney Govou|for Franck Ribér...
# 695  ['73&rsquor;|0:0|Lesław Ćmikiewicz|for Henryk ...
# 817                                                NaN
# 679  ['51&rsquor;|0:0|Antonio Biosca|for Migueli', ...
# ..                                                 ...
# 887                                                NaN
# 831                                                NaN
# 891                                                NaN
# 926                                                NaN
# 893                                                NaN
#
# [81 rows x 44 columns]

# %%
df[ScoreAboveZero & ScoreByBrazil].sort_values(by = 'home_score', ascending= True)
# Out:
#     home_team       away_team  home_score  home_xg  home_penalty  away_score  \
# 512    Brazil       Argentina           0      NaN           NaN           1
# 261    Brazil          France           0      NaN           NaN           1
# 695    Brazil          Poland           0      NaN           NaN           1
# 817    Brazil  Czechoslovakia           0      NaN           NaN           0
# 679    Brazil           Spain           0      NaN           NaN           0
# ..        ...             ...         ...      ...           ...         ...
# 887    Brazil          Mexico           5      NaN           NaN           0
# 831    Brazil          France           5      NaN           NaN           2
# 891    Brazil           Spain           6      NaN           NaN           1
# 926    Brazil          Poland           6      NaN           NaN           5
# 893    Brazil          Sweden           7      NaN           NaN           1
#
#      away_xg  away_penalty             home_manager  \
# 512      NaN           NaN       Sebastiao Lazaroni
# 261      NaN           NaN  Carlos Alberto Parreira
# 695      NaN           NaN            Mario Zagallo
# 817      NaN           NaN           Aymore Moreira
# 679      NaN           NaN         Claudio Coutinho
# ..       ...           ...                      ...
# 887      NaN           NaN             Zeze Moreira
# 831      NaN           NaN            Vicente Feola
# 891      NaN           NaN             Flavio Costa
# 926      NaN           NaN           Ademar Pimenta
# 893      NaN           NaN             Flavio Costa
#
#                   home_captain  ... home_penalty_shootout_miss_long  \
# 512              Ricardo Gomes  ...                             NaN
# 261                        NaN  ...                             NaN
# 695              Marinho Peres  ...                             NaN
# 817                Mauro Ramos  ...                             NaN
# 679               Émerson Leão  ...                             NaN
# ..                         ...  ...                             ...
# 887                      Bauer  ...                             NaN
# 831         Hilderaldo Bellini  ...                             NaN
# 891           Augusto da Costa  ...                             NaN
# 926  Martim Mércio da Silveira  ...                             NaN
# 893           Augusto da Costa  ...                             NaN
#
#     away_penalty_shootout_miss_long       home_red_card away_red_card  \
# 512                             NaN  Ricardo Gomes · 85           NaN
# 261                             NaN                 NaN           NaN
# 695                             NaN                 NaN           NaN
# 817                             NaN                 NaN           NaN
# 679                             NaN                 NaN           NaN
# ..                              ...                 ...           ...
# 887                             NaN                 NaN           NaN
# 831                             NaN                 NaN           NaN
# 891                             NaN                 NaN           NaN
# 926                             NaN                 NaN           NaN
# 893                             NaN                 NaN           NaN
#
#     home_yellow_red_card away_yellow_red_card  \
# 512                  NaN                  NaN
# 261                  NaN                  NaN
# 695                  NaN                  NaN
# 817                  NaN                  NaN
# 679                  NaN                  NaN
# ..                   ...                  ...
# 887                  NaN                  NaN
# 831                  NaN                  NaN
# 891                  NaN                  NaN
# 926                  NaN                  NaN
# 893                  NaN                  NaN
#
#                                  home_yellow_card_long  \
# 512  ['40&rsquor;|0:0|Ricardo Rocha', '50&rsquor;|0...
# 261  ['25&rsquor;|0:0|Cafú', '45&rsquor;|0:0|Juan',...
# 695                       ['76&rsquor;|0:1|Jairzinho']
# 817                                                NaN
# 679                                                NaN
# ..                                                 ...
# 887                                                NaN
# 831                                                NaN
# 891                           ['1&rsquor;|0:0|Bigode']
# 926                                                NaN
# 893                                                NaN
#
#                                  away_yellow_card_long  \
# 512  ['27&rsquor;|0:0|Pedro Monzón', '28&rsquor;|0:...
# 261  ['74&rsquor;|0:1|Willy Sagnol', '87&rsquor;|0:...
# 695               ['71&rsquor;|0:0|Henryk Kasperczak']
# 817                                                NaN
# 679                     ['1&rsquor;|0:0|Eugenio Leal']
# ..                                                 ...
# 887                                                NaN
# 831                                                NaN
# 891                                                NaN
# 926                                                NaN
# 893                                                NaN
#
#                                home_substitute_in_long  \
# 512  ['83&rsquor;|0:1|Silas Pereira', '83&rsquor;|0...
# 261  ['63&rsquor;|0:1|Adriano|for Juninho Pernambuc...
# 695   ['66&rsquor;|0:0|Mirandinha|for Ademir da Guia']
# 817                                                NaN
# 679  ['70&rsquor;|0:0|Gilberto Alves|for Nelinho', ...
# ..                                                 ...
# 887                                                NaN
# 831                                                NaN
# 891                                                NaN
# 926                                                NaN
# 893                                                NaN
#
#                                away_substitute_in_long
# 512  ['61&rsquor;|0:0|Gabriel Calderón|for Pedro Tr...
# 261  ['77&rsquor;|0:1|Sidney Govou|for Franck Ribér...
# 695  ['73&rsquor;|0:0|Lesław Ćmikiewicz|for Henryk ...
# 817                                                NaN
# 679  ['51&rsquor;|0:0|Antonio Biosca|for Migueli', ...
# ..                                                 ...
# 887                                                NaN
# 831                                                NaN
# 891                                                NaN
# 926                                                NaN
# 893                                                NaN
#
# [81 rows x 44 columns]

# %%
brazildf=df[ScoreAboveZero & ScoreByBrazil].sort_values(by = 'home_score', ascending= True)

# %%
brazildf
# Out:
#     home_team       away_team  home_score  home_xg  home_penalty  away_score  \
# 512    Brazil       Argentina           0      NaN           NaN           1
# 261    Brazil          France           0      NaN           NaN           1
# 695    Brazil          Poland           0      NaN           NaN           1
# 817    Brazil  Czechoslovakia           0      NaN           NaN           0
# 679    Brazil           Spain           0      NaN           NaN           0
# ..        ...             ...         ...      ...           ...         ...
# 887    Brazil          Mexico           5      NaN           NaN           0
# 831    Brazil          France           5      NaN           NaN           2
# 891    Brazil           Spain           6      NaN           NaN           1
# 926    Brazil          Poland           6      NaN           NaN           5
# 893    Brazil          Sweden           7      NaN           NaN           1
#
#      away_xg  away_penalty             home_manager  \
# 512      NaN           NaN       Sebastiao Lazaroni
# 261      NaN           NaN  Carlos Alberto Parreira
# 695      NaN           NaN            Mario Zagallo
# 817      NaN           NaN           Aymore Moreira
# 679      NaN           NaN         Claudio Coutinho
# ..       ...           ...                      ...
# 887      NaN           NaN             Zeze Moreira
# 831      NaN           NaN            Vicente Feola
# 891      NaN           NaN             Flavio Costa
# 926      NaN           NaN           Ademar Pimenta
# 893      NaN           NaN             Flavio Costa
#
#                   home_captain  ... home_penalty_shootout_miss_long  \
# 512              Ricardo Gomes  ...                             NaN
# 261                        NaN  ...                             NaN
# 695              Marinho Peres  ...                             NaN
# 817                Mauro Ramos  ...                             NaN
# 679               Émerson Leão  ...                             NaN
# ..                         ...  ...                             ...
# 887                      Bauer  ...                             NaN
# 831         Hilderaldo Bellini  ...                             NaN
# 891           Augusto da Costa  ...                             NaN
# 926  Martim Mércio da Silveira  ...                             NaN
# 893           Augusto da Costa  ...                             NaN
#
#     away_penalty_shootout_miss_long       home_red_card away_red_card  \
# 512                             NaN  Ricardo Gomes · 85           NaN
# 261                             NaN                 NaN           NaN
# 695                             NaN                 NaN           NaN
# 817                             NaN                 NaN           NaN
# 679                             NaN                 NaN           NaN
# ..                              ...                 ...           ...
# 887                             NaN                 NaN           NaN
# 831                             NaN                 NaN           NaN
# 891                             NaN                 NaN           NaN
# 926                             NaN                 NaN           NaN
# 893                             NaN                 NaN           NaN
#
#     home_yellow_red_card away_yellow_red_card  \
# 512                  NaN                  NaN
# 261                  NaN                  NaN
# 695                  NaN                  NaN
# 817                  NaN                  NaN
# 679                  NaN                  NaN
# ..                   ...                  ...
# 887                  NaN                  NaN
# 831                  NaN                  NaN
# 891                  NaN                  NaN
# 926                  NaN                  NaN
# 893                  NaN                  NaN
#
#                                  home_yellow_card_long  \
# 512  ['40&rsquor;|0:0|Ricardo Rocha', '50&rsquor;|0...
# 261  ['25&rsquor;|0:0|Cafú', '45&rsquor;|0:0|Juan',...
# 695                       ['76&rsquor;|0:1|Jairzinho']
# 817                                                NaN
# 679                                                NaN
# ..                                                 ...
# 887                                                NaN
# 831                                                NaN
# 891                           ['1&rsquor;|0:0|Bigode']
# 926                                                NaN
# 893                                                NaN
#
#                                  away_yellow_card_long  \
# 512  ['27&rsquor;|0:0|Pedro Monzón', '28&rsquor;|0:...
# 261  ['74&rsquor;|0:1|Willy Sagnol', '87&rsquor;|0:...
# 695               ['71&rsquor;|0:0|Henryk Kasperczak']
# 817                                                NaN
# 679                     ['1&rsquor;|0:0|Eugenio Leal']
# ..                                                 ...
# 887                                                NaN
# 831                                                NaN
# 891                                                NaN
# 926                                                NaN
# 893                                                NaN
#
#                                home_substitute_in_long  \
# 512  ['83&rsquor;|0:1|Silas Pereira', '83&rsquor;|0...
# 261  ['63&rsquor;|0:1|Adriano|for Juninho Pernambuc...
# 695   ['66&rsquor;|0:0|Mirandinha|for Ademir da Guia']
# 817                                                NaN
# 679  ['70&rsquor;|0:0|Gilberto Alves|for Nelinho', ...
# ..                                                 ...
# 887                                                NaN
# 831                                                NaN
# 891                                                NaN
# 926                                                NaN
# 893                                                NaN
#
#                                away_substitute_in_long
# 512  ['61&rsquor;|0:0|Gabriel Calderón|for Pedro Tr...
# 261  ['77&rsquor;|0:1|Sidney Govou|for Franck Ribér...
# 695  ['73&rsquor;|0:0|Lesław Ćmikiewicz|for Henryk ...
# 817                                                NaN
# 679  ['51&rsquor;|0:0|Antonio Biosca|for Migueli', ...
# ..                                                 ...
# 887                                                NaN
# 831                                                NaN
# 891                                                NaN
# 926                                                NaN
# 893                                                NaN
#
# [81 rows x 44 columns]

# %%
brazildf
# Out:
#     home_team       away_team  home_score  home_xg  home_penalty  away_score  \
# 512    Brazil       Argentina           0      NaN           NaN           1
# 261    Brazil          France           0      NaN           NaN           1
# 695    Brazil          Poland           0      NaN           NaN           1
# 817    Brazil  Czechoslovakia           0      NaN           NaN           0
# 679    Brazil           Spain           0      NaN           NaN           0
# ..        ...             ...         ...      ...           ...         ...
# 887    Brazil          Mexico           5      NaN           NaN           0
# 831    Brazil          France           5      NaN           NaN           2
# 891    Brazil           Spain           6      NaN           NaN           1
# 926    Brazil          Poland           6      NaN           NaN           5
# 893    Brazil          Sweden           7      NaN           NaN           1
#
#      away_xg  away_penalty             home_manager  \
# 512      NaN           NaN       Sebastiao Lazaroni
# 261      NaN           NaN  Carlos Alberto Parreira
# 695      NaN           NaN            Mario Zagallo
# 817      NaN           NaN           Aymore Moreira
# 679      NaN           NaN         Claudio Coutinho
# ..       ...           ...                      ...
# 887      NaN           NaN             Zeze Moreira
# 831      NaN           NaN            Vicente Feola
# 891      NaN           NaN             Flavio Costa
# 926      NaN           NaN           Ademar Pimenta
# 893      NaN           NaN             Flavio Costa
#
#                   home_captain  ... home_penalty_shootout_miss_long  \
# 512              Ricardo Gomes  ...                             NaN
# 261                        NaN  ...                             NaN
# 695              Marinho Peres  ...                             NaN
# 817                Mauro Ramos  ...                             NaN
# 679               Émerson Leão  ...                             NaN
# ..                         ...  ...                             ...
# 887                      Bauer  ...                             NaN
# 831         Hilderaldo Bellini  ...                             NaN
# 891           Augusto da Costa  ...                             NaN
# 926  Martim Mércio da Silveira  ...                             NaN
# 893           Augusto da Costa  ...                             NaN
#
#     away_penalty_shootout_miss_long       home_red_card away_red_card  \
# 512                             NaN  Ricardo Gomes · 85           NaN
# 261                             NaN                 NaN           NaN
# 695                             NaN                 NaN           NaN
# 817                             NaN                 NaN           NaN
# 679                             NaN                 NaN           NaN
# ..                              ...                 ...           ...
# 887                             NaN                 NaN           NaN
# 831                             NaN                 NaN           NaN
# 891                             NaN                 NaN           NaN
# 926                             NaN                 NaN           NaN
# 893                             NaN                 NaN           NaN
#
#     home_yellow_red_card away_yellow_red_card  \
# 512                  NaN                  NaN
# 261                  NaN                  NaN
# 695                  NaN                  NaN
# 817                  NaN                  NaN
# 679                  NaN                  NaN
# ..                   ...                  ...
# 887                  NaN                  NaN
# 831                  NaN                  NaN
# 891                  NaN                  NaN
# 926                  NaN                  NaN
# 893                  NaN                  NaN
#
#                                  home_yellow_card_long  \
# 512  ['40&rsquor;|0:0|Ricardo Rocha', '50&rsquor;|0...
# 261  ['25&rsquor;|0:0|Cafú', '45&rsquor;|0:0|Juan',...
# 695                       ['76&rsquor;|0:1|Jairzinho']
# 817                                                NaN
# 679                                                NaN
# ..                                                 ...
# 887                                                NaN
# 831                                                NaN
# 891                           ['1&rsquor;|0:0|Bigode']
# 926                                                NaN
# 893                                                NaN
#
#                                  away_yellow_card_long  \
# 512  ['27&rsquor;|0:0|Pedro Monzón', '28&rsquor;|0:...
# 261  ['74&rsquor;|0:1|Willy Sagnol', '87&rsquor;|0:...
# 695               ['71&rsquor;|0:0|Henryk Kasperczak']
# 817                                                NaN
# 679                     ['1&rsquor;|0:0|Eugenio Leal']
# ..                                                 ...
# 887                                                NaN
# 831                                                NaN
# 891                                                NaN
# 926                                                NaN
# 893                                                NaN
#
#                                home_substitute_in_long  \
# 512  ['83&rsquor;|0:1|Silas Pereira', '83&rsquor;|0...
# 261  ['63&rsquor;|0:1|Adriano|for Juninho Pernambuc...
# 695   ['66&rsquor;|0:0|Mirandinha|for Ademir da Guia']
# 817                                                NaN
# 679  ['70&rsquor;|0:0|Gilberto Alves|for Nelinho', ...
# ..                                                 ...
# 887                                                NaN
# 831                                                NaN
# 891                                                NaN
# 926                                                NaN
# 893                                                NaN
#
#                                away_substitute_in_long
# 512  ['61&rsquor;|0:0|Gabriel Calderón|for Pedro Tr...
# 261  ['77&rsquor;|0:1|Sidney Govou|for Franck Ribér...
# 695  ['73&rsquor;|0:0|Lesław Ćmikiewicz|for Henryk ...
# 817                                                NaN
# 679  ['51&rsquor;|0:0|Antonio Biosca|for Migueli', ...
# ..                                                 ...
# 887                                                NaN
# 831                                                NaN
# 891                                                NaN
# 926                                                NaN
# 893                                                NaN
#
# [81 rows x 44 columns]

# %%
brazildf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 81 entries, 512 to 893
# Data columns (total 44 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   home_team                        81 non-null     object
#  1   away_team                        81 non-null     object
#  2   home_score                       81 non-null     int64
#  3   home_xg                          7 non-null      float64
#  4   home_penalty                     0 non-null      float64
#  5   away_score                       81 non-null     int64
#  6   away_xg                          7 non-null      float64
#  7   away_penalty                     0 non-null      float64
#  8   home_manager                     81 non-null     object
#  9   home_captain                     59 non-null     object
#  10  away_manager                     81 non-null     object
#  11  away_captain                     59 non-null     object
#  12  Attendance                       81 non-null     int64
#  13  Venue                            81 non-null     object
#  14  Officials                        64 non-null     object
#  15  Round                            81 non-null     object
#  16  Date                             81 non-null     object
#  17  Score                            81 non-null     object
#  18  Referee                          64 non-null     object
#  19  Notes                            3 non-null      object
#  20  Host                             81 non-null     object
#  21  Year                             81 non-null     int64
#  22  home_goal                        71 non-null     object
#  23  away_goal                        38 non-null     object
#  24  home_goal_long                   71 non-null     object
#  25  away_goal_long                   38 non-null     object
#  26  home_own_goal                    2 non-null      object
#  27  away_own_goal                    2 non-null      object
#  28  home_penalty_goal                8 non-null      object
#  29  away_penalty_goal                8 non-null      object
#  30  home_penalty_miss_long           0 non-null      object
#  31  away_penalty_miss_long           0 non-null      object
#  32  home_penalty_shootout_goal_long  0 non-null      object
#  33  away_penalty_shootout_goal_long  0 non-null      object
#  34  home_penalty_shootout_miss_long  0 non-null      object
#  35  away_penalty_shootout_miss_long  0 non-null      object
#  36  home_red_card                    4 non-null      object
#  37  away_red_card                    3 non-null      object
#  38  home_yellow_red_card             1 non-null      object
#  39  away_yellow_red_card             3 non-null      object
#  40  home_yellow_card_long            43 non-null     object
#  41  away_yellow_card_long            47 non-null     object
#  42  home_substitute_in_long          51 non-null     object
#  43  away_substitute_in_long          55 non-null     object
# dtypes: float64(4), int64(4), object(36)
# memory usage: 28.5+ KB

# %%
# %matplotlib inline

# %%
from matplotlib import pyplot as plt

# %%
brazildf.plot(x='home_score',y='away_score',kind='scatter')
plt.xlabel('home_score')
plt.ylabel('away_score')
plt.title('Brazil Score')
plt.show()

# %%
brazildf.plot(x='home_score',y='away_score',kind='scatter')
plt.xlabel('home_score')
plt.ylabel('away_score')
plt.title('Brazil Score')
plt.show()

# %%
brazildf.plot(x='Year',y='home_score',kind='bar')
plt.xlabel('home_score')
plt.ylabel('away_score')
plt.title('Brazil Score')
plt.show()

# %%
def AnalyzeFrance():
  Matchesplayed = df['home_team'].value_counts()['France']
  print(f'Total Number of matches played by France is : {Matchesplayed}')

# %%
AnalyzeFrance()
# Out:
# Total Number of matches played by France is : 38

# %%
def AnalyzeTowns():
    TownData = df['home_team'].value_counts()
    for _ in TownData.index:
     print(f'Total Number ofmatches ofplayed by{_} is:(TownData[_])')

# %%
AnalyzeTowns()
# Out:
# Total Number ofmatches ofplayed byBrazil is:(TownData[_])
# Total Number ofmatches ofplayed byArgentina is:(TownData[_])
# Total Number ofmatches ofplayed byItaly is:(TownData[_])
# Total Number ofmatches ofplayed byEngland is:(TownData[_])
# Total Number ofmatches ofplayed byGermany is:(TownData[_])
# Total Number ofmatches ofplayed byFrance is:(TownData[_])
# Total Number ofmatches ofplayed byWest Germany is:(TownData[_])
# Total Number ofmatches ofplayed bySpain is:(TownData[_])
# Total Number ofmatches ofplayed byNetherlands is:(TownData[_])
# Total Number ofmatches ofplayed byUruguay is:(TownData[_])
# Total Number ofmatches ofplayed bySweden is:(TownData[_])
# Total Number ofmatches ofplayed byBelgium is:(TownData[_])
# Total Number ofmatches ofplayed byPortugal is:(TownData[_])
# Total Number ofmatches ofplayed byPoland is:(TownData[_])
# Total Number ofmatches ofplayed bySoviet Union is:(TownData[_])
# Total Number ofmatches ofplayed byHungary is:(TownData[_])
# Total Number ofmatches ofplayed byMexico is:(TownData[_])
# Total Number ofmatches ofplayed byKorea Republic is:(TownData[_])
# Total Number ofmatches ofplayed bySwitzerland is:(TownData[_])
# Total Number ofmatches ofplayed byUnited States is:(TownData[_])
# Total Number ofmatches ofplayed byYugoslavia is:(TownData[_])
# Total Number ofmatches ofplayed byJapan is:(TownData[_])
# Total Number ofmatches ofplayed byChile is:(TownData[_])
# Total Number ofmatches ofplayed byCameroon is:(TownData[_])
# Total Number ofmatches ofplayed byAustria is:(TownData[_])
# Total Number ofmatches ofplayed byParaguay is:(TownData[_])
# Total Number ofmatches ofplayed byNigeria is:(TownData[_])
# Total Number ofmatches ofplayed byDenmark is:(TownData[_])
# Total Number ofmatches ofplayed byCzechoslovakia is:(TownData[_])
# Total Number ofmatches ofplayed byCroatia is:(TownData[_])
# Total Number ofmatches ofplayed byScotland is:(TownData[_])
# Total Number ofmatches ofplayed byRomania is:(TownData[_])
# Total Number ofmatches ofplayed byColombia is:(TownData[_])
# Total Number ofmatches ofplayed byMorocco is:(TownData[_])
# Total Number ofmatches ofplayed bySaudi Arabia is:(TownData[_])
# Total Number ofmatches ofplayed byAustralia is:(TownData[_])
# Total Number ofmatches ofplayed byCosta Rica is:(TownData[_])
# Total Number ofmatches ofplayed byTunisia is:(TownData[_])
# Total Number ofmatches ofplayed byBulgaria is:(TownData[_])
# Total Number ofmatches ofplayed byPeru is:(TownData[_])
# Total Number ofmatches ofplayed bySouth Africa is:(TownData[_])
# Total Number ofmatches ofplayed byRussia is:(TownData[_])
# Total Number ofmatches ofplayed byAlgeria is:(TownData[_])
# Total Number ofmatches ofplayed byEcuador is:(TownData[_])
# Total Number ofmatches ofplayed byIR Iran is:(TownData[_])
# Total Number ofmatches ofplayed byGhana is:(TownData[_])
# Total Number ofmatches ofplayed byRepublic of Ireland is:(TownData[_])
# Total Number ofmatches ofplayed byHonduras is:(TownData[_])
# Total Number ofmatches ofplayed byNorthern Ireland is:(TownData[_])
# Total Number ofmatches ofplayed bySerbia is:(TownData[_])
# Total Number ofmatches ofplayed byGreece is:(TownData[_])
# Total Number ofmatches ofplayed bySenegal is:(TownData[_])
# Total Number ofmatches ofplayed byKorea DPR is:(TownData[_])
# Total Number ofmatches ofplayed byGermany DR is:(TownData[_])
# Total Number ofmatches ofplayed bySlovenia is:(TownData[_])
# Total Number ofmatches ofplayed byCôte d'Ivoire is:(TownData[_])
# Total Number ofmatches ofplayed byWales is:(TownData[_])
# Total Number ofmatches ofplayed byIraq is:(TownData[_])
# Total Number ofmatches ofplayed byZaire is:(TownData[_])
# Total Number ofmatches ofplayed byCuba is:(TownData[_])
# Total Number ofmatches ofplayed byCanada is:(TownData[_])
# Total Number ofmatches ofplayed byQatar is:(TownData[_])
# Total Number ofmatches ofplayed bySlovakia is:(TownData[_])
# Total Number ofmatches ofplayed byCzech Republic is:(TownData[_])
# Total Number ofmatches ofplayed byTogo is:(TownData[_])
# Total Number ofmatches ofplayed byTürkiye is:(TownData[_])
# Total Number ofmatches ofplayed byChina PR is:(TownData[_])
# Total Number ofmatches ofplayed byUnited Arab Emirates is:(TownData[_])
# Total Number ofmatches ofplayed byHaiti is:(TownData[_])
# Total Number ofmatches ofplayed byPanama is:(TownData[_])
# Total Number ofmatches ofplayed byIceland is:(TownData[_])
# Total Number ofmatches ofplayed byEgypt is:(TownData[_])
# Total Number ofmatches ofplayed byUkraine is:(TownData[_])
# Total Number ofmatches ofplayed byNew Zealand is:(TownData[_])
# Total Number ofmatches ofplayed byNorway is:(TownData[_])
# Total Number ofmatches ofplayed byBolivia is:(TownData[_])
# Total Number ofmatches ofplayed bySerbia and Montenegro is:(TownData[_])
# Total Number ofmatches ofplayed byJamaica is:(TownData[_])
# Total Number ofmatches ofplayed byFR Yugoslavia is:(TownData[_])
# Total Number ofmatches ofplayed byAngola is:(TownData[_])
# Total Number ofmatches ofplayed byTrinidad and Tobago is:(TownData[_])
# Total Number ofmatches ofplayed byBosnia and Herzegovina is:(TownData[_])

# %%
# %matplotlib inline

# %%
Town30 = df ['home_team']. value_counts()

# %%
Town30
# Out:
# home_team
# Brazil                    85
# Argentina                 59
# Italy                     57
# England                   40
# Germany                   40
#                           ..
# Jamaica                    1
# FR Yugoslavia              1
# Angola                     1
# Trinidad and Tobago        1
# Bosnia and Herzegovina     1
# Name: count, Length: 82, dtype: int64

# %%
townName=[]
matchesplayed=[]
TownDate=df['home_team'].value_counts()
for _ in TownDate.index:
  if TownDate[_]>30:
   townName.append(_)
   matchesplayed.append(TownDate [_])

# %%
from matplotlib import pyplot as plt

# %%
plt.plot(townName,matchesplayed)
plt.ylabel('Matches Played')
plt.xlabel('Town Name')
plt.title('Matches Played by Towns')
plt.show()

# %%
plt.bar(townName,matchesplayed)
plt.ylabel('Matches Played')
plt.xlabel('Town Name')
plt.title('Matches Played by Towns')
plt.show()

# %%
def matchesplayedbyTown():
  townName =[]
  matchesplayed = []
  Towndata = df['home_team'].value_counts()
  for _ in TownData.index:
    if TownData[_] >30:
     townName.append(_)
     matchesplayed.append(TownData[_])
  plt.bar(townName,matchesplayed)
  plt.ylabel('Matches Played')
  plt.xlabel('Town Name')
  plt.title('Matches Played by Towns')
  plt.show()

# %%
plt.barh(townName,matchesplayed)
plt.ylabel('Matches Played')
plt.xlabel('Town Name')
plt.title('Matches Played by Towns')
plt.show()

# %%
def MatchesplayedByTown2():
   Above30 = df['home_team'].value_counts()
   filteredData = Above30[Above30> 30]
   filteredData.plot(kind = 'barh')

# %%
MatchesplayedByTown2()

# %%
import random

# %%
age = []
height = []
weight = []

# %%
df
# Out:
#          home_team away_team  home_score  home_xg  home_penalty  away_score  \
# 0        Argentina    France           3      3.3           4.0           3
# 1          Croatia   Morocco           2      0.7           NaN           1
# 2           France   Morocco           2      2.0           NaN           0
# 3        Argentina   Croatia           3      2.3           NaN           0
# 4          Morocco  Portugal           1      1.4           NaN           0
# ..             ...       ...         ...      ...           ...         ...
# 959      Argentina    France           1      NaN           NaN           0
# 960     Yugoslavia    Brazil           2      NaN           NaN           1
# 961        Romania      Peru           3      NaN           NaN           1
# 962  United States   Belgium           3      NaN           NaN           0
# 963         France    Mexico           4      NaN           NaN           1
#
#      away_xg  away_penalty      home_manager          home_captain  ...  \
# 0        2.2           2.0    Lionel Scaloni          Lionel Messi  ...
# 1        1.2           NaN      Zlatko Dalić           Luka Modrić  ...
# 2        0.9           NaN  Didier Deschamps           Hugo Lloris  ...
# 3        0.5           NaN    Lionel Scaloni          Lionel Messi  ...
# 4        0.9           NaN   Hoalid Regragui          Romain Saïss  ...
# ..       ...           ...               ...                   ...  ...
# 959      NaN           NaN  Francisco Olazar       Manuel Ferreira  ...
# 960      NaN           NaN   Bosko Simonovic       Milutin Ivković  ...
# 961      NaN           NaN     Octav Luchide          Emerich Vogl  ...
# 962      NaN           NaN        Bob Millar            Tom Florie  ...
# 963      NaN           NaN     Raoul Caudron  Alexandre Villaplane  ...
#
#     home_penalty_shootout_miss_long  \
# 0                               NaN
# 1                               NaN
# 2                               NaN
# 3                               NaN
# 4                               NaN
# ..                              ...
# 959                             NaN
# 960                             NaN
# 961                             NaN
# 962                             NaN
# 963                             NaN
#
#                        away_penalty_shootout_miss_long  home_red_card  \
# 0    ['3|1:1|Kingsley Coman', '5|2:1|Aurélien Tchou...            NaN
# 1                                                  NaN            NaN
# 2                                                  NaN            NaN
# 3                                                  NaN            NaN
# 4                                                  NaN            NaN
# ..                                                 ...            ...
# 959                                                NaN            NaN
# 960                                                NaN            NaN
# 961                                                NaN            NaN
# 962                                                NaN            NaN
# 963                                                NaN            NaN
#
#             away_red_card   home_yellow_red_card away_yellow_red_card  \
# 0                     NaN                    NaN                  NaN
# 1                     NaN                    NaN                  NaN
# 2                     NaN                    NaN                  NaN
# 3                     NaN                    NaN                  NaN
# 4                     NaN  Walid Cheddira · 90+3                  NaN
# ..                    ...                    ...                  ...
# 959                   NaN                    NaN                  NaN
# 960                   NaN                    NaN                  NaN
# 961  Plácido Galindo · 70                    NaN                  NaN
# 962                   NaN                    NaN                  NaN
# 963                   NaN                    NaN                  NaN
#
#                                  home_yellow_card_long  \
# 0    ['45+7&rsquor;|2:0|Enzo Fernández', '90+8&rsqu...
# 1                                                  NaN
# 2                                                  NaN
# 3    ['68&rsquor;|2:0|Cristian Romero', '71&rsquor;...
# 4    ['70&rsquor;|1:0|Achraf Dari', '90+1&rsquor;|1...
# ..                                                 ...
# 959                                                NaN
# 960                                                NaN
# 961                                                NaN
# 962                                                NaN
# 963                                                NaN
#
#                                  away_yellow_card_long  \
# 0    ['55&rsquor;|2:0|Adrien Rabiot', '87&rsquor;|2...
# 1    ['69&rsquor;|2:1|Azzedine Ounahi', '84&rsquor;...
# 2                    ['27&rsquor;|1:0|Sofiane Boufal']
# 3    ['32&rsquor;|0:0|Mateo Kovačić', '32&rsquor;|0...
# 4                           ['87&rsquor;|1:0|Vitinha']
# ..                                                 ...
# 959                                                NaN
# 960                                                NaN
# 961                                                NaN
# 962                                                NaN
# 963                                                NaN
#
#                                home_substitute_in_long  \
# 0    ['64&rsquor;|2:0|Marcos Acuña|for Ángel Di Mar...
# 1    ['61&rsquor;|2:1|Nikola Vlašić|for Andrej Kram...
# 2    ['65&rsquor;|1:0|Marcus Thuram|for Olivier Gir...
# 3    ['62&rsquor;|2:0|Lisandro Martínez|for Leandro...
# 4    ['57&rsquor;|1:0|Achraf Dari|for Romain Saïss'...
# ..                                                 ...
# 959                                                NaN
# 960                                                NaN
# 961                                                NaN
# 962                                                NaN
# 963                                                NaN
#
#                                away_substitute_in_long
# 0    ['41&rsquor;|2:0|Randal Kolo Muani|for Ousmane...
# 1    ['46&rsquor;|2:1|Ilias Chair|for Abdelhamid Sa...
# 2    ['21&rsquor;|1:0|Selim Amallah|for Romain Saïs...
# 3    ['46&rsquor;|2:0|Mislav Oršić|for Borna Sosa',...
# 4    ['51&rsquor;|1:0|João Cancelo|for Raphaël Guer...
# ..                                                 ...
# 959                                                NaN
# 960                                                NaN
# 961                                                NaN
# 962                                                NaN
# 963                                                NaN
#
# [964 rows x 44 columns]

# %%
df.shape
# Out:
# (964, 44)

# %%
# loop comprehension
[age.append(random.randint(18,40)) for _ in range(964)]
print(f"age is now having{len(age)}")
# Out:
# age is now having964

# %%
age
# Out:
# [21,
#  22,
#  20,
#  32,
#  29,
#  36,
#  25,
#  19,
#  38,
#  37,
#  25,
#  39,
#  32,
#  36,
#  26,
#  31,
#  36,
#  22,
#  39,
#  30,
#  24,
#  31,
#  29,
#  20,
#  36,
#  22,
#  30,
#  32,
#  40,
#  20,
#  31,
#  19,
#  21,
#  38,
#  31,
#  23,
#  22,
#  29,
#  22,
#  24,
#  23,
#  29,
#  25,
#  39,
#  31,
#  31,
#  29,
#  24,
#  31,
#  26,
#  35,
#  18,
#  28,
#  39,
#  21,
#  34,
#  28,
#  34,
#  32,
#  28,
#  36,
#  30,
#  24,
#  23,
#  24,
#  33,
#  20,
#  20,
#  32,
#  30,
#  39,
#  31,
#  26,
#  22,
#  35,
#  27,
#  38,
#  38,
#  40,
#  28,
#  32,
#  36,
#  39,
#  29,
#  40,
#  38,
#  31,
#  31,
#  25,
#  23,
#  25,
#  24,
#  24,
#  18,
#  36,
#  28,
#  24,
#  20,
#  40,
#  36,
#  31,
#  30,
#  33,
#  21,
#  40,
#  40,
#  38,
#  39,
#  40,
#  36,
#  29,
#  28,
#  28,
#  33,
#  32,
#  35,
#  28,
#  40,
#  29,
#  30,
#  36,
#  28,
#  37,
#  26,
#  20,
#  30,
#  23,
#  21,
#  29,
#  29,
#  25,
#  27,
#  22,
#  18,
#  40,
#  35,
#  24,
#  35,
#  25,
#  39,
#  40,
#  27,
#  27,
#  20,
#  32,
#  28,
#  24,
#  22,
#  35,
#  36,
#  30,
#  27,
#  22,
#  39,
#  18,
#  28,
#  19,
#  20,
#  33,
#  19,
#  34,
#  20,
#  30,
#  26,
#  27,
#  37,
#  32,
#  21,
#  28,
#  22,
#  20,
#  25,
#  22,
#  35,
#  18,
#  35,
#  21,
#  34,
#  22,
#  32,
#  40,
#  38,
#  36,
#  38,
#  28,
#  37,
#  38,
#  34,
#  21,
#  40,
#  20,
#  37,
#  21,
#  21,
#  36,
#  28,
#  33,
#  23,
#  22,
#  40,
#  26,
#  31,
#  26,
#  33,
#  21,
#  23,
#  38,
#  21,
#  22,
#  27,
#  35,
#  23,
#  37,
#  32,
#  39,
#  40,
#  26,
#  32,
#  33,
#  37,
#  23,
#  25,
#  27,
#  39,
#  18,
#  24,
#  28,
#  39,
#  39,
#  37,
#  29,
#  31,
#  33,
#  26,
#  33,
#  23,
#  34,
#  35,
#  25,
#  20,
#  27,
#  31,
#  21,
#  33,
#  21,
#  27,
#  19,
#  18,
#  26,
#  35,
#  28,
#  23,
#  22,
#  29,
#  27,
#  27,
#  24,
#  37,
#  36,
#  38,
#  36,
#  34,
#  38,
#  34,
#  18,
#  40,
#  20,
#  35,
#  36,
#  20,
#  30,
#  37,
#  37,
#  31,
#  26,
#  28,
#  37,
#  21,
#  27,
#  25,
#  25,
#  33,
#  19,
#  21,
#  27,
#  24,
#  19,
#  32,
#  39,
#  28,
#  40,
#  23,
#  28,
#  24,
#  23,
#  35,
#  40,
#  40,
#  31,
#  25,
#  27,
#  35,
#  26,
#  28,
#  24,
#  36,
#  19,
#  34,
#  20,
#  28,
#  35,
#  23,
#  40,
#  23,
#  38,
#  29,
#  36,
#  18,
#  20,
#  26,
#  24,
#  36,
#  36,
#  31,
#  38,
#  27,
#  31,
#  40,
#  25,
#  32,
#  27,
#  21,
#  40,
#  37,
#  32,
#  29,
#  38,
#  37,
#  19,
#  40,
#  34,
#  19,
#  28,
#  33,
#  26,
#  22,
#  38,
#  20,
#  38,
#  25,
#  24,
#  39,
#  20,
#  20,
#  25,
#  34,
#  28,
#  21,
#  31,
#  29,
#  40,
#  37,
#  32,
#  24,
#  24,
#  32,
#  32,
#  18,
#  34,
#  36,
#  38,
#  20,
#  34,
#  20,
#  37,
#  27,
#  23,
#  31,
#  22,
#  33,
#  27,
#  24,
#  38,
#  27,
#  29,
#  29,
#  40,
#  30,
#  32,
#  23,
#  30,
#  23,
#  29,
#  35,
#  38,
#  18,
#  18,
#  27,
#  34,
#  23,
#  37,
#  39,
#  37,
#  22,
#  26,
#  36,
#  26,
#  22,
#  30,
#  34,
#  39,
#  33,
#  33,
#  34,
#  24,
#  22,
#  30,
#  23,
#  25,
#  25,
#  33,
#  36,
#  22,
#  18,
#  34,
#  26,
#  26,
#  40,
#  26,
#  19,
#  18,
#  23,
#  33,
#  35,
#  37,
#  22,
#  27,
#  33,
#  40,
#  28,
#  24,
#  32,
#  21,
#  40,
#  19,
#  18,
#  38,
#  38,
#  35,
#  18,
#  25,
#  19,
#  32,
#  30,
#  33,
#  25,
#  39,
#  29,
#  20,
#  30,
#  23,
#  20,
#  28,
#  23,
#  37,
#  29,
#  26,
#  39,
#  20,
#  27,
#  26,
#  29,
#  38,
#  30,
#  26,
#  29,
#  19,
#  28,
#  40,
#  36,
#  33,
#  32,
#  39,
#  31,
#  27,
#  26,
#  27,
#  28,
#  30,
#  35,
#  35,
#  30,
#  25,
#  31,
#  34,
#  25,
#  18,
#  27,
#  31,
#  38,
#  23,
#  18,
#  39,
#  35,
#  39,
#  26,
#  22,
#  33,
#  36,
#  40,
#  27,
#  28,
#  18,
#  32,
#  36,
#  40,
#  25,
#  39,
#  38,
#  35,
#  22,
#  26,
#  21,
#  19,
#  30,
#  33,
#  19,
#  21,
#  39,
#  19,
#  20,
#  35,
#  35,
#  19,
#  28,
#  20,
#  31,
#  33,
#  21,
#  22,
#  20,
#  34,
#  36,
#  29,
#  38,
#  40,
#  34,
#  21,
#  37,
#  39,
#  30,
#  40,
#  30,
#  37,
#  29,
#  40,
#  38,
#  40,
#  39,
#  23,
#  18,
#  31,
#  38,
#  23,
#  25,
#  39,
#  35,
#  35,
#  29,
#  36,
#  32,
#  20,
#  27,
#  37,
#  30,
#  27,
#  30,
#  30,
#  36,
#  26,
#  39,
#  35,
#  40,
#  28,
#  29,
#  34,
#  27,
#  25,
#  40,
#  20,
#  22,
#  38,
#  33,
#  24,
#  27,
#  18,
#  37,
#  33,
#  39,
#  40,
#  25,
#  28,
#  31,
#  23,
#  25,
#  33,
#  35,
#  22,
#  24,
#  22,
#  23,
#  24,
#  37,
#  20,
#  27,
#  40,
#  35,
#  29,
#  19,
#  34,
#  25,
#  20,
#  20,
#  25,
#  36,
#  20,
#  38,
#  38,
#  34,
#  20,
#  30,
#  37,
#  24,
#  35,
#  19,
#  36,
#  39,
#  23,
#  24,
#  33,
#  33,
#  19,
#  20,
#  28,
#  40,
#  39,
#  27,
#  33,
#  39,
#  22,
#  21,
#  36,
#  32,
#  22,
#  35,
#  22,
#  18,
#  23,
#  34,
#  36,
#  29,
#  26,
#  22,
#  29,
#  20,
#  36,
#  27,
#  22,
#  24,
#  19,
#  34,
#  25,
#  31,
#  21,
#  20,
#  39,
#  18,
#  20,
#  32,
#  18,
#  34,
#  22,
#  23,
#  21,
#  18,
#  19,
#  21,
#  24,
#  40,
#  38,
#  34,
#  33,
#  31,
#  22,
#  23,
#  24,
#  37,
#  38,
#  36,
#  18,
#  32,
#  30,
#  35,
#  24,
#  18,
#  35,
#  30,
#  35,
#  40,
#  38,
#  32,
#  40,
#  28,
#  18,
#  24,
#  19,
#  30,
#  23,
#  24,
#  35,
#  30,
#  22,
#  20,
#  33,
#  30,
#  38,
#  25,
#  31,
#  21,
#  33,
#  40,
#  31,
#  31,
#  18,
#  26,
#  22,
#  21,
#  32,
#  22,
#  39,
#  29,
#  34,
#  26,
#  36,
#  23,
#  40,
#  26,
#  35,
#  26,
#  39,
#  23,
#  32,
#  27,
#  37,
#  36,
#  36,
#  40,
#  20,
#  18,
#  23,
#  36,
#  34,
#  33,
#  30,
#  24,
#  37,
#  21,
#  33,
#  39,
#  38,
#  32,
#  33,
#  21,
#  18,
#  29,
#  25,
#  29,
#  29,
#  40,
#  34,
#  35,
#  39,
#  26,
#  36,
#  26,
#  25,
#  18,
#  37,
#  36,
#  35,
#  24,
#  22,
#  37,
#  31,
#  30,
#  21,
#  18,
#  38,
#  28,
#  31,
#  19,
#  35,
#  23,
#  27,
#  19,
#  30,
#  23,
#  25,
#  30,
#  25,
#  27,
#  40,
#  37,
#  18,
#  25,
#  39,
#  20,
#  36,
#  20,
#  31,
#  26,
#  39,
#  39,
#  36,
#  30,
#  30,
#  31,
#  32,
#  18,
#  34,
#  24,
#  36,
#  38,
#  29,
#  24,
#  35,
#  22,
#  35,
#  29,
#  38,
#  21,
#  19,
#  40,
#  31,
#  27,
#  36,
#  29,
#  34,
#  31,
#  28,
#  39,
#  25,
#  24,
#  37,
#  21,
#  33,
#  24,
#  20,
#  18,
#  31,
#  20,
#  38,
#  40,
#  21,
#  38,
#  22,
#  38,
#  30,
#  28,
#  31,
#  28,
#  18,
#  21,
#  19,
#  38,
#  36,
#  35,
#  32,
#  32,
#  26,
#  34,
#  31,
#  19,
#  26,
#  29,
#  27,
#  40,
#  27,
#  34,
#  18,
#  33,
#  19,
#  37,
#  32,
#  22,
#  37,
#  31,
#  29,
#  36,
#  29,
#  26,
#  37,
#  33,
#  31,
#  23,
#  21,
#  23,
#  36,
#  21,
#  32,
#  31,
#  32,
#  30,
#  27,
#  35,
#  27,
#  24,
#  30,
#  20,
#  39,
#  21,
#  34,
#  26,
#  19,
#  22,
#  30,
#  30,
#  18,
#  40,
#  22,
#  31,
#  35,
#  23,
#  26,
#  30,
#  19,
#  19,
#  32,
#  35,
#  22,
#  28,
#  37,
#  18,
#  25,
#  36,
#  35,
#  24,
#  29,
#  30,
#  25,
#  29,
#  24,
#  31,
#  26,
#  26,
#  36,
#  21,
#  36,
#  32,
#  28,
#  24,
#  34,
#  27,
#  19,
#  26,
#  36,
#  24,
#  20,
#  24,
#  30,
#  33,
#  23,
#  36,
#  34,
#  20,
#  31,
#  25,
#  26,
#  33,
#  25,
#  26,
#  22,
#  24,
#  35,
#  36,
#  27,
#  32,
#  23,
#  25,
#  36,
#  38,
#  34,
#  35,
#  40,
#  23,
#  33,
#  30,
#  22,
#  22,
#  27,
#  ...]

# %%
#adding a new column to DFrame
#syntax:df('newcolumnname"]=list/series

# %%
df['yearsofexperience']=age

# %%
df['ASP'] = df['yearsofexperience']-df['home_score']

# %%
df.shape
# Out:
# (964, 46)

# %%
df
# Out:
#          home_team away_team  home_score  home_xg  home_penalty  away_score  \
# 0        Argentina    France           3      3.3           4.0           3
# 1          Croatia   Morocco           2      0.7           NaN           1
# 2           France   Morocco           2      2.0           NaN           0
# 3        Argentina   Croatia           3      2.3           NaN           0
# 4          Morocco  Portugal           1      1.4           NaN           0
# ..             ...       ...         ...      ...           ...         ...
# 959      Argentina    France           1      NaN           NaN           0
# 960     Yugoslavia    Brazil           2      NaN           NaN           1
# 961        Romania      Peru           3      NaN           NaN           1
# 962  United States   Belgium           3      NaN           NaN           0
# 963         France    Mexico           4      NaN           NaN           1
#
#      away_xg  away_penalty      home_manager          home_captain  ...  \
# 0        2.2           2.0    Lionel Scaloni          Lionel Messi  ...
# 1        1.2           NaN      Zlatko Dalić           Luka Modrić  ...
# 2        0.9           NaN  Didier Deschamps           Hugo Lloris  ...
# 3        0.5           NaN    Lionel Scaloni          Lionel Messi  ...
# 4        0.9           NaN   Hoalid Regragui          Romain Saïss  ...
# ..       ...           ...               ...                   ...  ...
# 959      NaN           NaN  Francisco Olazar       Manuel Ferreira  ...
# 960      NaN           NaN   Bosko Simonovic       Milutin Ivković  ...
# 961      NaN           NaN     Octav Luchide          Emerich Vogl  ...
# 962      NaN           NaN        Bob Millar            Tom Florie  ...
# 963      NaN           NaN     Raoul Caudron  Alexandre Villaplane  ...
#
#     home_red_card         away_red_card   home_yellow_red_card  \
# 0             NaN                   NaN                    NaN
# 1             NaN                   NaN                    NaN
# 2             NaN                   NaN                    NaN
# 3             NaN                   NaN                    NaN
# 4             NaN                   NaN  Walid Cheddira · 90+3
# ..            ...                   ...                    ...
# 959           NaN                   NaN                    NaN
# 960           NaN                   NaN                    NaN
# 961           NaN  Plácido Galindo · 70                    NaN
# 962           NaN                   NaN                    NaN
# 963           NaN                   NaN                    NaN
#
#     away_yellow_red_card                              home_yellow_card_long  \
# 0                    NaN  ['45+7&rsquor;|2:0|Enzo Fernández', '90+8&rsqu...
# 1                    NaN                                                NaN
# 2                    NaN                                                NaN
# 3                    NaN  ['68&rsquor;|2:0|Cristian Romero', '71&rsquor;...
# 4                    NaN  ['70&rsquor;|1:0|Achraf Dari', '90+1&rsquor;|1...
# ..                   ...                                                ...
# 959                  NaN                                                NaN
# 960                  NaN                                                NaN
# 961                  NaN                                                NaN
# 962                  NaN                                                NaN
# 963                  NaN                                                NaN
#
#                                  away_yellow_card_long  \
# 0    ['55&rsquor;|2:0|Adrien Rabiot', '87&rsquor;|2...
# 1    ['69&rsquor;|2:1|Azzedine Ounahi', '84&rsquor;...
# 2                    ['27&rsquor;|1:0|Sofiane Boufal']
# 3    ['32&rsquor;|0:0|Mateo Kovačić', '32&rsquor;|0...
# 4                           ['87&rsquor;|1:0|Vitinha']
# ..                                                 ...
# 959                                                NaN
# 960                                                NaN
# 961                                                NaN
# 962                                                NaN
# 963                                                NaN
#
#                                home_substitute_in_long  \
# 0    ['64&rsquor;|2:0|Marcos Acuña|for Ángel Di Mar...
# 1    ['61&rsquor;|2:1|Nikola Vlašić|for Andrej Kram...
# 2    ['65&rsquor;|1:0|Marcus Thuram|for Olivier Gir...
# 3    ['62&rsquor;|2:0|Lisandro Martínez|for Leandro...
# 4    ['57&rsquor;|1:0|Achraf Dari|for Romain Saïss'...
# ..                                                 ...
# 959                                                NaN
# 960                                                NaN
# 961                                                NaN
# 962                                                NaN
# 963                                                NaN
#
#                                away_substitute_in_long yearsofexperience ASP
# 0    ['41&rsquor;|2:0|Randal Kolo Muani|for Ousmane...                18  15
# 1    ['46&rsquor;|2:1|Ilias Chair|for Abdelhamid Sa...                23  21
# 2    ['21&rsquor;|1:0|Selim Amallah|for Romain Saïs...                29  27
# 3    ['46&rsquor;|2:0|Mislav Oršić|for Borna Sosa',...                22  19
# 4    ['51&rsquor;|1:0|João Cancelo|for Raphaël Guer...                25  24
# ..                                                 ...               ...  ..
# 959                                                NaN                21  20
# 960                                                NaN                33  31
# 961                                                NaN                35  32
# 962                                                NaN                40  37
# 963                                                NaN                34  30
#
# [964 rows x 46 columns]

# %%
# %matplotlib inline

# %%
from matplotlib import pyplot as plt

# %%
df.plot(x='yearsofexperience',y='ASP',kind ='scatter', color='yellow')
# Out:
# <Axes: xlabel='yearsofexperience', ylabel='ASP'>

# %%
df.plot(x='yearsofexperience',y='ASP',kind ='bar', color=['blue','green'])
# Out:
# <Axes: xlabel='yearsofexperience'>

# %%
# Function to get a graph
def getGraph(Dataframe, column1 , column2):
  from matplotlib import pyplot as plt

  #Check the length of column1 and column2
  if len(Dataframe[column1]) == len(Dataframe[column2]):
     df.plot(x = column1, y = column2, kind = 'bar', color = ['black','pink'])
     print('The graph/plot is succesfully created')

  else :
       print('Please check the column size once')

# %%
getGraph(df, 'home_score','away_score')
# Out:
# The graph/plot is succesfully created
